# %%
import requests
from bs4 import BeautifulSoup
import couchdb

# %% [markdown]
# ## Conectando con el servidor

# %%
couch = couchdb.Server('http://admin:admin@25.8.48.217:5984/')

# %% [markdown]
# ## Nombre de la base de datos

# %%
db = couch['target']

# %%
url = 'https://edu.gcfglobal.org/es/informatica-basica/que-es-un-computador/1/'
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text,'html.parser')

# %%
links = soup.find_all('a')
data = []

for link in links:
    href = link.get('href')
    text = link.text
    data.append({'href': href,'text': text,'autor':'Juan Gualotuña'})

# %%
for item in data:
    db.save(item)

# %%
data
# Out:
# [{'href': '#',
#   'text': '',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744a75a5',
#   '_rev': '1-719a4b999866dcbef22229a12fe902d6'},
#  {'href': '/es/',
#   'text': '\n\n',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744a8388',
#   '_rev': '1-09fcb272d183bba45da430b5a6bb91f7'},
#  {'href': '/es/subjects/tecnologia/',
#   'text': 'Tecnología',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744a857e',
#   '_rev': '1-5e655557b13ec37e019560905fafb580'},
#  {'href': '/es/informatica-basica/',
#   'text': 'Informática básica',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744a8be0',
#   '_rev': '1-136d361567b2a78afbafac1ce12ead8a'},
#  {'href': '/es/crear-un-correo-electronico/',
#   'text': 'Correo electrónico',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744a986e',
#   '_rev': '1-68436c5c412596277cc6419776215e90'},
#  {'href': '/es/word-2013/',
#   'text': 'Word 2013',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744a9b17',
#   '_rev': '1-6527e9ce83dce492191fc1c08816141c'},
#  {'href': '/es/microsoft-excel-2010/',
#   'text': 'Excel 2010',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744aa0f8',
#   '_rev': '1-031a0121e2c0a073a1091d7498d1317f'},
#  {'href': '/es/crear-cuenta-en-facebook/',
#   'text': 'Facebook',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744aa814',
#   '_rev': '1-94f239cee4ffe7f5dd01c82db3bdf82d'},
#  {'href': '/es/subjects/tecnologia/',
#   'text': 'Más cursos...',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744aa919',
#   '_rev': '1-a98cc0886e337403743eb86c1a5575fe'},
#  {'href': '/es/subjects/matematicas/',
#   'text': 'Matemáticas',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744aad65',
#   '_rev': '1-7b251b57704a83719b9a55b8ed74782d'},
#  {'href': '/es/los-conjuntos/',
#   'text': 'Los conjuntos',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744aba10',
#   '_rev': '1-b1cf9e16daa037b7cb2c2923f9e685aa'},
#  {'href': '/es/fraccionarios/',
#   'text': 'Fraccionarios',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744ac29c',
#   '_rev': '1-e51d5c6ae9daa0547b32fcb4c821a91a'},
#  {'href': '/es/los-numeros/',
#   'text': 'Los números',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744aca77',
#   '_rev': '1-4440b599ad301376acaa6c8547b8107a'},
#  {'href': '/es/sumar-y-restar/',
#   'text': 'Sumar y restar',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744acfc5',
#   '_rev': '1-1a3796cb9f3dea1fb30d57b10029b630'},
#  {'href': '/es/divisores-y-multiplos/',
#   'text': 'Divisores y múltiplos',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744adbde',
#   '_rev': '1-471823d6d0e4c56246fca3098f8f62d7'},
#  {'href': '/es/algebra/',
#   'text': 'Álgebra',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744ae882',
#   '_rev': '1-6ba370f17d7cdea434a8a8808955eb4b'},
#  {'href': '/es/subjects/matematicas/',
#   'text': 'Más cursos...',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744af867',
#   '_rev': '1-daeae681787d290d5abda1dd83db7897'},
#  {'href': '/es/subjects/formacion-profesional/',
#   'text': 'Formación profesional',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b05d2',
#   '_rev': '1-d9dedcc4de533f1e42ea9a0bab1e949c'},
#  {'href': '/es/credito/',
#   'text': 'Crédito',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b0b04',
#   '_rev': '1-fb2aeb29f7ff8dae3207497a637a25d7'},
#  {'href': '/es/emprendimiento/',
#   'text': 'Emprendimiento',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b186a',
#   '_rev': '1-01c2d06b366617627f71126ed8383b50'},
#  {'href': '/es/mundo-laboral/',
#   'text': 'Mundo laboral',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b1faf',
#   '_rev': '1-22b5e5ea339371c06c70df53dde45ebc'},
#  {'href': '/es/acceso-a-la-educacion-superior/',
#   'text': 'Acceso a la educación superior',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b2133',
#   '_rev': '1-5b0b916fe85865cf87eafe667dcdb565'},
#  {'href': '/es/finanzas-personales/',
#   'text': 'Finanzas personales',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b25f7',
#   '_rev': '1-b8ebf8891f2b5f2c25188301d5b202ef'},
#  {'href': '/es/curso-de-fotografia-digital/',
#   'text': 'Curso de fotografía digital',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b2d09',
#   '_rev': '1-a0bc21bf344b4a9b1275d54c10b69eda'},
#  {'href': '/es/subjects/formacion-profesional/',
#   'text': 'Más cursos...',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b2f4b',
#   '_rev': '1-890f7e3bb57bb59d6a4cbab8caf9f6c1'},
#  {'href': 'https://idiomas.gcfglobal.org/es/',
#   'text': 'Inglés',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b2fb2',
#   '_rev': '1-2d4f66d9debb7baba0cce89eade1a4ec'},
#  {'href': 'https://idiomas.gcfglobal.org/es/curso/ingles/a1/',
#   'text': 'Beginner',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b32ec',
#   '_rev': '1-810fec2bd6ffa1d5c124ac6a78624af3'},
#  {'href': 'https://idiomas.gcfglobal.org/es/curso/ingles/a2/',
#   'text': 'Basic',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b3e7a',
#   '_rev': '1-0b8486362c5fc9030ab2116f221cec68'},
#  {'href': 'https://idiomas.gcfglobal.org/es/curso/ingles/b1/',
#   'text': 'Intermediate',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b4116',
#   '_rev': '1-b99ae4781ee89e10d5fc2f168dff8f76'},
#  {'href': 'https://idiomas.gcfglobal.org/es/curso/ingles/b2/',
#   'text': 'Upper intermediate',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b4dbe',
#   '_rev': '1-8d050163413f165628d739c3498bedc8'},
#  {'href': 'https://idiomas.gcfglobal.org/es/curso/ingles/c1/',
#   'text': 'Advanced',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b513f',
#   '_rev': '1-a30a61f6fe639d810b3716d661ded327'},
#  {'href': 'https://www.juegosparaaprenderingles.org/',
#   'text': 'Juegos',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b5d32',
#   '_rev': '1-2b2f9e212ef6143726f8d7a853937d3a'},
#  {'href': '/es/topics/',
#   'text': 'Todos los cursos',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b69ce',
#   '_rev': '1-b0afbd80cfbc80be7aa460600a056970'},
#  {'href': '/es/',
#   'text': '\r\n\t\t\t\t\t\t\t\t\t\t\tEspañol\r\n\t\t\t\t\t\t\t\t\t\t\texpand_more\nexpand_less\n',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b7050',
#   '_rev': '1-ad5ff0a266952910367d988f5ebe8da4'},
#  {'href': '/pt/',
#   'text': '\r\n\t\t\t\t\t\t\t\t\t\t\tPortuguês\r\n\t\t\t\t\t\t\t\t\t\t',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b782f',
#   '_rev': '1-e40de0a19f00fc25e4b3401d5128a427'},
#  {'href': '/en/',
#   'text': '\r\n\t\t\t\t\t\t\t\t\t\t\tEnglish\r\n\t\t\t\t\t\t\t\t\t\t',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b7aa4',
#   '_rev': '1-6657880d4b18c834b57c7134aa16744a'},
#  {'href': '/es/informatica-basica/',
#   'text': 'Informática Básica',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b7e31',
#   '_rev': '1-a569395ffdb79900dcdf1f4966b4c481'},
#  {'href': '/es/informatica-basica/',
#   'text': 'Ir al curso',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b8386',
#   '_rev': '1-72d4f05cfaf9c2aa4f6c9750abdd3312'},
#  {'href': '/',
#   'text': '\n\n\n',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b8a23',
#   '_rev': '1-77d48847b20ca6adfbe27074560e1f1c'},
#  {'href': '#',
#   'text': '',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b9491',
#   '_rev': '1-719a4b999866dcbef22229a12fe902d6'},
#  {'href': '/es/topics/',
#   'text': 'Todos los cursos',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744b99d3',
#   '_rev': '1-b0afbd80cfbc80be7aa460600a056970'},
#  {'href': '/es/info/quienes-somos/1/',
#   'text': '¿Quiénes somos?',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744ba22b',
#   '_rev': '1-de788adbff6e44efc63ead6cbbe6146c'},
#  {'href': '/es/info/preguntas-frecuentes/1/',
#   'text': 'Preguntas frecuentes',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744bae69',
#   '_rev': '1-2efa8d46985a73f1d41b4f3ca48c0022'},
#  {'href': '/es/info/contactanos/1/',
#   'text': 'Contáctanos',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744bb53e',
#   '_rev': '1-739e32feccb2a458ff81f59a195c8b83'},
#  {'href': '/en/',
#   'text': 'EN',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744bba88',
#   '_rev': '1-f5f91473eeb3e9c496e94ce10cd9695f'},
#  {'href': '/es/',
#   'text': 'ES',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744bc098',
#   '_rev': '1-a633239a63466a890db2a64657f01ae2'},
#  {'href': '/pt/',
#   'text': 'PT',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744bc68d',
#   '_rev': '1-2f1b6c27ca2848c9af41e77667932fcd'},
#  {'href': 'https://account.gcfglobal.org/',
#   'text': 'Ingresar',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744bd63e',
#   '_rev': '1-5d05cd6f851bd0e4fa766d53fdeb3c2b'},
#  {'href': 'https://account.gcfglobal.org/signup',
#   'text': '¡Crear cuenta!',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744bd886',
#   '_rev': '1-c4f1459975d9099af37a216f8a340022'},
#  {'href': 'https://account.gcfglobal.org/home',
#   'text': 'Panel de usuario',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744be001',
#   '_rev': '1-50c92908224afe17728bbc251d93d766'},
#  {'href': 'https://account.gcfglobal.org/profile',
#   'text': 'Perfil',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744beb0d',
#   '_rev': '1-4f39a49525c6a57be7d7409663f217a6'},
#  {'href': 'https://account.gcfglobal.org/auth/logout',
#   'text': 'Cerrar sesión',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744bed98',
#   '_rev': '1-28b37642d69e993359adf720c2e87acb'},
#  {'href': '/es/informatica-basica/',
#   'text': '\nnavigate_before Curso\n',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744bf271',
#   '_rev': '1-91d45b0882ae649acfb1d9023dc98c45'},
#  {'href': 'https://edu.gcfglobal.org/es/topics/microsoft-office/',
#   'text': 'elaborar cartas o una hoja de vida',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744bf325',
#   '_rev': '1-b62ae0ae542d9b311aee4a1a335e75bc'},
#  {'href': 'https://edu.gcfglobal.org/es/como-manejar-tu-dinero/como-hacer-un-presupuesto/1/',
#   'text': 'hacer presupuestos',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744bfa11',
#   '_rev': '1-96c5f6569e17621ff7e5ff7e34ffa252'},
#  {'href': 'https://edu.gcfglobal.org/es/como-usar-internet/que-es-un-navegador/1/',
#   'text': 'navegar en internet',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744bff02',
#   '_rev': '1-e877e77eb823239ad920b76db27517cd'},
#  {'href': None,
#   'text': '\n\nContinuar\n',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744c0be4',
#   '_rev': '1-626e7582c5117b4fe5169527ab84373f'},
#  {'href': '/es/informatica-basica/',
#   'text': 'Return to Playlist: Informática Básica',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744c0fbc',
#   '_rev': '1-d00f0b60ee2d4411a93963d6cc58fb85'},
#  {'href': '/es/informatica-basica/encender-el-computador-de-escritorio/1/',
#   'text': '\nCargar:Encender el computador de escritorio\n',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744c1bad',
#   '_rev': '1-cd6b64a14232d266485b130bb5280513'},
#  {'href': '/es/info/quienes-somos/1/',
#   'text': '¿Quiénes somos?',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744c23d3',
#   '_rev': '1-de788adbff6e44efc63ead6cbbe6146c'},
#  {'href': '/es/info/equipo-de-trabajo/1/',
#   'text': 'Equipo de trabajo',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744c2f6b',
#   '_rev': '1-0a6890f8cfc1230bb47013be5725c838'},
#  {'href': 'https://careers.gcfglobal.org/',
#   'text': 'Trabaja con nosotros',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744c3b56',
#   '_rev': '1-57a556d4726e02bcb10c92d5714e66f9'},
#  {'href': 'https://partners.gcfglobal.org/es',
#   'text': 'Asóciate con nosotros',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744c3de4',
#   '_rev': '1-e1564317a10307bf6dadbe719d4f52bb'},
#  {'href': 'https://aprender.gcfglobal.org/es-material-docente',
#   'text': 'Espacio docente',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744c4201',
#   '_rev': '1-0e5daef6cce3fb2ad13e96648a1791fa'},
#  {'href': '/es/info/preguntas-frecuentes/1/',
#   'text': 'Preguntas frecuentes',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744c4efc',
#   '_rev': '1-2efa8d46985a73f1d41b4f3ca48c0022'},
#  {'href': '/es/info/condiciones-de-servicio/1/',
#   'text': 'Condiciones de Servicio',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744c5957',
#   '_rev': '1-e49e14f2fad58afe32965ed76820e910'},
#  {'href': '/es/info/politica-de-privacidad/1/',
#   'text': 'Política de Privacidad',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744c5f2d',
#   '_rev': '1-7f2c58db58987f1d0c5e29045707432a'},
#  {'href': '/es/info/politica-de-cookies/1/',
#   'text': 'Política de Cookies',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744c649f',
#   '_rev': '1-ded5b153b6baf8347ba8d47edf55b8be'},
#  {'href': '/es/info/contactanos/1/',
#   'text': 'Contáctanos',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744c72eb',
#   '_rev': '1-739e32feccb2a458ff81f59a195c8b83'},
#  {'href': 'https://www.facebook.com/GCFAprendeLibre',
#   'text': '\n\n',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744c7476',
#   '_rev': '1-e8a7dcdbe81628f2ef797fc302739a60'},
#  {'href': 'https://twitter.com/GCFAprendeLibre',
#   'text': '\n\n',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744c7be8',
#   '_rev': '1-2c887478ba80393e723fa1b646a37871'},
#  {'href': 'https://www.youtube.com/GCFAprendeLibre',
#   'text': '\n\n',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744c82b8',
#   '_rev': '1-86c459f2136a420a346ea0682f88a1fb'},
#  {'href': 'https://pinterest.com/GCFAprendeLibre/',
#   'text': '\n\n',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744c8f64',
#   '_rev': '1-dca7c7fe0b73a2c1fe11db22b5a9cd1b'},
#  {'href': 'https://instagram.com/gcfaprendelibre/',
#   'text': '\n\n',
#   'autor': 'Juan Gualotuña',
#   '_id': 'c0a135cbfb949cfdec53e8d5744c9b7a',
#   '_rev': '1-b36cc6b4fe6c2d05ede40dad0e059448'}]
